# %%
from nltk.tree import Tree
import nltk
from benepar2 import ptb_unescape, tetra_tag, retokenization
from transformers import AutoConfig, GPT2TokenizerFast
import numpy as np

# %%
tree = Tree.fromstring("""(TOP
  (S
    (PP
      (IN In)
      (NP
        (NP (DT an) (NNP Oct.) (CD 19) (NN review))
        (PP
          (IN of)
          (NP
            (`` ``)
            (NP (DT The) (NN Misanthrope))
            ('' '')
            (PP
              (IN at)
              (NP
                (NP (NNP Chicago) (POS 's))
                (NNP Goodman)
                (NNP Theatre)))))
        (PRN
          (-LRB- -LRB-)
          (`` ``)
          (S
            (NP (JJ Revitalized) (NNS Classics))
            (VP
              (VBP Take)
              (NP (DT the) (NNP Stage))
              (PP (IN in) (NP (NNP Windy) (NNP City)))))
          (, ,)
          ('' '')
          (NP (NNP Leisure) (CC &) (NNP Arts))
          (-RRB- -RRB-))))
    (, ,)
    (NP
      (NP (NP (DT the) (NN role)) (PP (IN of) (NP (NNP Celimene))))
      (, ,)
      (VP (VBN played) (PP (IN by) (NP (NNP Kim) (NNP Cattrall))))
      (, ,))
    (VP
      (VBD was)
      (VP
        (ADVP (RB mistakenly))
        (VBN attributed)
        (PP (TO to) (NP (NNP Christina) (NNP Haag)))))
    (. .)))
""")
tree
# Out:
# Tree('TOP', [Tree('S', [Tree('PP', [Tree('IN', ['In']), Tree('NP', [Tree('NP', [Tree('DT', ['an']), Tree('NNP', ['Oct.']), Tree('CD', ['19']), Tree('NN', ['review'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('``', ['``']), Tree('NP', [Tree('DT', ['The']), Tree('NN', ['Misanthrope'])]), Tree("''", ["''"]), Tree('PP', [Tree('IN', ['at']), Tree('NP', [Tree('NP', [Tree('NNP', ['Chicago']), Tree('POS', ["'s"])]), Tree('NNP', ['Goodman']), Tree('NNP', ['Theatre'])])])])]), Tree('PRN', [Tree('-LRB-', ['-LRB-']), Tree('``', ['``']), Tree('S', [Tree('NP', [Tree('JJ', ['Revitalized']), Tree('NNS', ['Classics'])]), Tree('VP', [Tree('VBP', ['Take']), Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['Stage'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Windy']), Tree('NNP', ['City'])])])])]), Tree(',', [',']), Tree("''", ["''"]), Tree('NP', [Tree('NNP', ['Leisure']), Tree('CC', ['&']), Tree('NNP', ['Arts'])]), Tree('-RRB-', ['-RRB-'])])])]), Tree(',', [',']), Tree('NP', [T
# ...

# %%
class TreeProcess():
    def __init__(self):
        config = AutoConfig.from_pretrained(
            'kitaev/tetra-tag-en')
        tag_vocab = [config.id2label[i]
                     for i in sorted(config.id2label.keys())]
        self.tetra_tag_system = tetra_tag.TetraTagSystem(tag_vocab=tag_vocab)

        tag_ind = sorted(set([tag[1:]
                              for tag in self.tetra_tag_system.tag_vocab]))
        self.tag_ind = {tag: i for i, tag in enumerate(tag_ind)}
        self.tag_from_ind = tag_ind
        self.tetra_tag_ind = {'L': 0, 'R': 1, 'l': 2, 'r': 3}
        for i, p in enumerate(nltk.load('help/tagsets/upenn_tagset.pickle').keys(), 4):
            self.tetra_tag_ind[p] = i

    def simple_tags_and_labels(self, tree, return_tetra=False):
        pos = nltk.pos_tag(tree.leaves())
        pos_iter = iter(pos)
        tags = self.tetra_tag_system.tags_from_tree(tree)
        x = np.zeros((len(tags), len(self.tetra_tag_ind)))
        y, att, not_leaves, in_tags = [], [], [], []
        for i, tag in enumerate(tags):
            att.append(True)
            if return_tetra:
                in_tags.append(tag[0])
            x[i, self.tetra_tag_ind[tag[0]]] = 1
            leaf = False
            if tag[0] in 'lr':
                _, p = next(pos_iter)
                x[i, self.tetra_tag_ind[p]] = 1
                leaf = True
            not_leaves.append(not leaf)
            y.append(self.tag_ind[tag[1:]])
        ret = {'input': x, 'attention_mask': np.array(att), 
               'not_leaves': np.array(not_leaves), 'labels': np.array(y)}
        if return_tetra:
            ret['tetra_tags'] = in_tags
            ret['pos'] = pos
        return ret
    
    def tree_from_preds(self, tetra_tags, labels, pos):
        tags = [t + self.tag_from_ind[label] for t, label in zip(tetra_tags, labels)]
        return self.tetra_tag_system.tree_from_tags(tags, pos=pos)

    def get_tag_label_vocab(self):
        return self.tetra_tag_ind, self.tag_ind

# %%
process = TreeProcess()

# %%
r = process.simple_tags_and_labels(tree, True)

# %%
process.tree_from_preds(r['tetra_tags'], r['labels'])
# Out:
# ['l', 'L/PP', 'l', 'L/NP', 'l', 'R', 'l', 'R', 'r', 'R/NP', 'l', 'L/PP', 'l', 'R/NP', 'l', 'L/NP', 'r', 'R', 'l', 'R', 'l', 'R/PP', 'l', 'L/NP', 'r', 'R/NP', 'l', 'R', 'r', 'R', 'l', 'R/PRN', 'l', 'R', 'l', 'L/NP', 'r', 'L/S', 'l', 'R/VP', 'l', 'L/NP', 'r', 'R', 'l', 'R/PP', 'l', 'R/NP', 'r', 'R', 'l', 'R', 'l', 'R', 'l', 'L/NP', 'l', 'R', 'r', 'R', 'r', 'L/S', 'l', 'R', 'l', 'L/NP', 'r', 'L/NP', 'l', 'R/PP', 'r/NP', 'L/NP', 'l', 'R', 'l', 'L/VP', 'l', 'R/PP', 'l', 'R/NP', 'r', 'R', 'r', 'R', 'l', 'L/VP', 'l/ADVP', 'R/VP', 'l', 'R', 'l', 'R/PP', 'l', 'R/NP', 'r', 'R', 'r']
# ...

# %%
import nltk
tagdict = nltk.load('help/tagsets/upenn_tagset.pickle')

# %%
len(tagdict.keys())
# Out:
# 45

# %%
tetra_tag_ind = {'L': 0, 'R': 1, 'l': 2, 'r': 3}
pos_ind = {p: i for i, p in enumerate(nltk.load('help/tagsets/upenn_tagset.pickle').keys())}
def get_tags_and_labels(tree):
    pos = iter(nltk.pos_tag(tree.leaves()))
    tags = tetra_tag_system.tags_from_tree(tree)
    # 45 pos tags, 4 tetra tags
    x = np.zeros((len(tags), 49))
    y = []
    for i, tag in enumerate(tags):
        x[i, tetra_tag_ind[tag[0]]] = 1
        if tag[0] in 'lr':
            word, p = next(pos)
            x[i, 4 + pos_ind[p]] = 1
        y.append(tag_ind[tag[1:]])
    return x, np.array(y)

# %%
x, y = get_tags_and_labels(tree)
# Out:
# 0

# %%
b = x[0]
b[2 ] = 0
np.argmax(b)
# Out:
# 29

# %%
list(pos_ind.keys())[29]
# Out:
# 'IN'
